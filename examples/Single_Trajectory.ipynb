# %%
import scanpy as sc

from bio_grns import (
    Trajectory,
    GRNSimulator
)

# %%
### Construct a trajectory ###

trajectory_1 = Trajectory(
    500,                           ### Length of trajectory in time units (minutes)
    primary_trajectory = True,     ### Trajectory is primary (represents wall clock)
    force_positive = True,         ### Return absolute value of activity
    latent_network_sparsity = 0.2, ### Ratio of TFs which will be influenced by this trajectory
    name = "Development"           ### Name this trajectory
)

trajectory_1.add_pattern(
    'random', 0.5, 0.05, 0.2
) ### Random walk starting with an activity of 1 and steps between 0.05 and 0.2

trajectory_1.add_pattern(
    'cyclic', 0, 0.01, 0.5
) ### Cycle from zero to one (halfway through the trajectory) to zero again with random step sizes between 0.01 and 0.5

trajectory_1.add_pattern(
    'updown', .8, .2, (0.01, 0.5)
) ### Cycle from .8 to 1 (20% into the trajectory) to 0 with random step sizes between 0.01 and 0.5

# %%
### Create a simulator ###

sim = GRNSimulator(
    5000,    ### Number of genes
    200,     ### Number of genes which are regulators
    1000,    ### Number of samples to generate
    5000,    ### Number of read counts per sample
    81,      ### Random number for seeding generator
    debug=True
)

sim.add_trajectory(trajectory_1)   ### Add the trajectory to the simulator
sim.simulate()
# Out:
# 2022-11-04 15:10:26,325 Generating trajectory -> regulator networks
# 2022-11-04 15:10:26,327 Generated (200, 3) network with 39 nonzero edges
# 2022-11-04 15:10:26,327 Generated network for Development
# 2022-11-04 15:10:26,327 Simulating gene biophysical parameters
# 2022-11-04 15:10:26,328 Simulating regulatory network
# 2022-11-04 15:10:26,365 Generated (5000, 200) network with 29916 nonzero edges
# 2022-11-04 15:10:26,366 Simulating gene expression over time
# 2022-11-04 15:10:26,367 Generating pattern gene expression for Development
# 2022-11-04 15:10:26,368 Generating pattern regulatory activity for Development
# 2022-11-04 15:10:26,368 Generating pattern dynamic states for Development

# %%
adata = sim.generate_count_data()
# Out:
# 2022-11-04 15:10:26,569 Simulating count data from trajectories
# 100%|██████████| 1000/1000 [00:00<00:00, 1569.41it/s]

# %%
sc.pp.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.pl.umap(adata, color="Development", title="Time on Development Trajectory")
